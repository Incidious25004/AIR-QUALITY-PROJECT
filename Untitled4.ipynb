# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data_date.csv")
df.head()
# Out:
#          Date    Country                          Status  AQI Value
# 0  2022-07-21    Albania                            Good         14
# 1  2022-07-21    Algeria                        Moderate         65
# 2  2022-07-21    Andorra                        Moderate         55
# 3  2022-07-21     Angola  Unhealthy for Sensitive Groups        113
# 4  2022-07-21  Argentina                        Moderate         63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17877 entries, 0 to 17876
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       17877 non-null  object
#  1   Country    17877 non-null  object
#  2   Status     17877 non-null  object
#  3   AQI Value  17877 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 558.8+ KB

# %%
df.describe()
# Out:
#           AQI Value
# count  17877.000000
# mean      63.523578
# std       50.128197
# min        1.000000
# 25%       29.000000
# 50%       53.000000
# 75%       83.000000
# max      963.000000

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for i in ["Country","Status","Date"]:
  df[i] = label_encoder.fit_transform(df[i])

# %%
x=df.drop(columns=["AQI Value"])
y=df["AQI Value"]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

# Print results
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Mean Absolute Error: 16.410595386835446
# Mean Squared Error: 960.7536260742356
# R-squared Score: 0.6042655058958843
